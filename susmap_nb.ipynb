# %%
import pandas as pd

ft = pd.read_csv("fairtrade30.csv")

ft.head(10)
# Out:
#                                    Organization  \
# 0                        Mayorga Organics, LLC.
# 1                            Peregrine Espresso
# 2                            Peregrine Espresso
# 3                            Peregrine Espresso
# 4                         Ten Thousand Villages
# 5  Trade Roots, Fair Trade Gift and Coffee Shop
# 6                              Fair Trade Winds
# 7                                 Indus Imports
# 8                                 Qualia Coffee
# 9                                 Qualia Coffee
#
#                  Street Address Line One Street Address Line Two        City  \
# 0                                    BWI           Concourse A/B   Baltimore
# 1                660 Pennsylvania Ave SE                     NaN  Washington
# 2                        1718 14th St NW                     NaN  Washington
# 3                         1309 5th St NE                     NaN  Washington
# ...
